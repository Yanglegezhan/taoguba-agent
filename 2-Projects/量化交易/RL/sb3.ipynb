# %%
import os

print(os.getcwd())
# Out:
# /home/adminroot/Tacrypto

# %%
import gymnasium as gym

from stable_baselines3 import A2C

env = gym.make("CartPole-v1", render_mode="rgb_array")

model = A2C("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=10_000)

vec_env = model.get_env()
obs = vec_env.reset()
for i in range(1000):
    action, _state = model.predict(obs, deterministic=True)
    obs, reward, done, info = vec_env.step(action)
    vec_env.render("human")
    # VecEnv resets automatically
    if done:
        obs = vec_env.reset()
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 22.9     |
# |    ep_rew_mean        | 22.9     |
# | time/                 |          |
# |    fps                | 304      |
# |    iterations         | 100      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -0.692   |
# |    explained_variance | 0.782    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | 0.819    |
# |    value_loss         | 1.55     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 21.6     |
# |    ep_rew_mean        | 21.6     |
# | time/                 |          |
# |    fps                | 339      |
# |    iterations         | 200      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -0.685   |
# |    explained_variance | -0.124   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | -2.47    |
# |    value_loss         | 63.8     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 22.4     |
# |    ep_rew_mean        | 22.4     |
# | time/                 |          |
# |    fps                | 374      |
# |    iterations         | 300      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -0.689   |
# |    explained_variance | -0.0109  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | 1.6      |
# |    value_loss         | 7.07     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 25.5     |
# |    ep_rew_mean        | 25.5     |
# | time/                 |          |
# |    fps                | 413      |
# |    iterations         | 400      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -0.677   |
# |    explained_variance | -0.0799  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | 1.27     |
# |    value_loss         | 6.7      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 27.1     |
# |    ep_rew_mean        | 27.1     |
# | time/                 |          |
# |    fps                | 440      |
# |    iterations         | 500      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -0.661   |
# |    explained_variance | -0.02    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 1.29     |
# |    value_loss         | 5.9      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 29.7     |
# |    ep_rew_mean        | 29.7     |
# | time/                 |          |
# |    fps                | 460      |
# |    iterations         | 600      |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -0.674   |
# |    explained_variance | 0.00155  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 1.16     |
# |    value_loss         | 5.28     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 33.2      |
# |    ep_rew_mean        | 33.2      |
# | time/                 |           |
# |    fps                | 475       |
# |    iterations         | 700       |
# |    time_elapsed       | 7         |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -0.601    |
# |    explained_variance | -0.000173 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | -10.8     |
# |    value_loss         | 804       |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 36       |
# |    ep_rew_mean        | 36       |
# | time/                 |          |
# |    fps                | 487      |
# |    iterations         | 800      |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -0.635   |
# |    explained_variance | 0.00413  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 1.06     |
# |    value_loss         | 4.13     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 40.3     |
# |    ep_rew_mean        | 40.3     |
# | time/                 |          |
# |    fps                | 497      |
# |    iterations         | 900      |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -0.67    |
# |    explained_variance | 7.87e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | 0.863    |
# |    value_loss         | 3.57     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 43.3     |
# |    ep_rew_mean        | 43.3     |
# | time/                 |          |
# |    fps                | 505      |
# |    iterations         | 1000     |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.614   |
# |    explained_variance | 0.000316 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 0.98     |
# |    value_loss         | 3.09     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 47.1     |
# |    ep_rew_mean        | 47.1     |
# | time/                 |          |
# |    fps                | 512      |
# |    iterations         | 1100     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -0.472   |
# |    explained_variance | 0.000773 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 0.95     |
# |    value_loss         | 2.63     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 51.9      |
# |    ep_rew_mean        | 51.9      |
# | time/                 |           |
# |    fps                | 518       |
# |    iterations         | 1200      |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -0.621    |
# |    explained_variance | -2.11e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1199      |
# |    policy_loss        | 0.698     |
# |    value_loss         | 2.22      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 55.5     |
# |    ep_rew_mean        | 55.5     |
# | time/                 |          |
# |    fps                | 524      |
# |    iterations         | 1300     |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -0.546   |
# |    explained_variance | -0.00108 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | 0.474    |
# |    value_loss         | 1.82     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 60.7     |
# |    ep_rew_mean        | 60.7     |
# | time/                 |          |
# |    fps                | 528      |
# |    iterations         | 1400     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -0.644   |
# |    explained_variance | 0.000193 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | 0.556    |
# |    value_loss         | 1.47     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 63.6      |
# |    ep_rew_mean        | 63.6      |
# | time/                 |           |
# |    fps                | 532       |
# |    iterations         | 1500      |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -0.633    |
# |    explained_variance | -5.29e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | 0.492     |
# |    value_loss         | 1.14      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 68.4     |
# |    ep_rew_mean        | 68.4     |
# | time/                 |          |
# |    fps                | 536      |
# |    iterations         | 1600     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -0.584   |
# |    explained_variance | 0.000589 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | 0.453    |
# |    value_loss         | 0.853    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 74.5      |
# |    ep_rew_mean        | 74.5      |
# | time/                 |           |
# |    fps                | 539       |
# |    iterations         | 1700      |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -0.655    |
# |    explained_variance | -1.28e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | 0.332     |
# |    value_loss         | 0.61      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 77.3     |
# |    ep_rew_mean        | 77.3     |
# | time/                 |          |
# |    fps                | 542      |
# |    iterations         | 1800     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -0.626   |
# |    explained_variance | 2.32e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | 0.299    |
# |    value_loss         | 0.411    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 82.4     |
# |    ep_rew_mean        | 82.4     |
# | time/                 |          |
# |    fps                | 544      |
# |    iterations         | 1900     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -0.344   |
# |    explained_variance | 4.08e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | 0.17     |
# |    value_loss         | 0.248    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 86.8     |
# |    ep_rew_mean        | 86.8     |
# | time/                 |          |
# |    fps                | 547      |
# |    iterations         | 2000     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.417   |
# |    explained_variance | 1.45e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.254    |
# |    value_loss         | 0.133    |
# ------------------------------------

# %%
import gymnasium as gym
env = gym.make("LunarLander-v2", render_mode="human")
observation, info = env.reset()

for _ in range(1000):
    action = env.action_space.sample()  # agent policy that uses the observation and info
    observation, reward, terminated, truncated, info = env.step(action)

    if terminated or truncated:
        observation, info = env.reset()

env.close()

# %%
import gymnasium as gym
from gymnasium.wrappers import FlattenObservation

# %%
env = gym.make("CarRacing-v2")

# %%
env.observation_space.shape
# Out:
# (96, 96, 3)

# %%
print(env.observation_space)
# Out:
# Box(0, 255, (96, 96, 3), uint8)

# %%
wrapped_env = FlattenObservation(env)
wrapped_env.observation_space.shape
# Out:
# (27648,)

# %%
wrapped_env
# Out:
# <FlattenObservation<TimeLimit<OrderEnforcing<PassiveEnvChecker<CarRacing<CarRacing-v2>>>>>>

# %%
wrapped_env.unwrapped

# %%
import gym

env = gym.make("CarRacing-v0", apply_api_compatibility=True)
# Out:
# /home/adminroot/anaconda3/envs/CX/lib/python3.10/site-packages/gym/envs/registration.py:555: UserWarning: WARN: The environment CarRacing-v0 is out of date. You should consider upgrading to version `v2`.
#   logger.warn(
# ---------------------------------------------------------------------------
# DeprecatedEnv                             Traceback (most recent call last)
# Cell In[10], line 3
#       1 import gym
# ----> 3 env = gym.make("CarRacing-v0", apply_api_compatibility=True)
#
# File ~/anaconda3/envs/CX/lib/python3.10/site-packages/gym/envs/registration.py:569, in make(id, max_episode_steps, autoreset, apply_api_compatibility, disable_env_checker, **kwargs)
#     563         logger.warn(
#     564             f"Using the latest versioned environment `{new_env_id}` "
#     565             f"instead of the unversioned environment `{id}`."
#     566         )
#     568     if spec_ is None:
# --> 569         _check_version_exists(ns, name, version)
#     570         raise error.Error(f"No registered env with id: {id}")
#     572 _kwargs = spec_.kwargs.copy()
#
# File ~/anaconda3/envs/CX/lib/python3.10/site-packages/gym/envs/registration.py:251, in _check_version_exists(ns, name, version)
#     248     raise error.VersionNotFound(message)
#     250 if latest_spec is not None and version < latest_spec.version:
# --> 251     raise error.DeprecatedEnv(
#     252         f"Environment version v{version} for `{get_env_id(ns, name, None)}` is deprecated. "
#     253         f"Please use `{latest_spec.id}` instead."
#     254     )
#
# DeprecatedEnv: Environment version v0 for `CarRacing` is deprecated. Please use `CarRacing-v2` instead.
